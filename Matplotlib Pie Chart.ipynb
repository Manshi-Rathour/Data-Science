# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
exp_values = [1400, 600, 300, 410, 250]
exp_labels = ['Home rent', 'Food', 'Phone/Internet Bill', 'Car', 'Other Utilities']
plt.pie(exp_values, labels = exp_labels, radius = 1)
plt.show()

# %%
exp_values = [1400, 600, 300, 410, 250]
exp_labels = ['Home rent', 'Food', 'Phone/Internet Bill', 'Car', 'Other Utilities']
plt.pie(exp_values, labels = exp_labels, radius = 1, autopct = '%0.1f%%', shadow = True, explode = [0, 0.2, 0.2, 0, 0],
       startangle = 45)
plt.show()
