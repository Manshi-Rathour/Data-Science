# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Weather.csv')
df
# Out:
#            day      city  temperature  windspeed  event
# 0   01-01-2023    mumbai           32          7  sunny
# 1   02-01-2023    mumbai           30          9    fog
# 2   03-01-2023    mumbai           29          6    fog
# 3   04-01-2023    mumbai           28         10   rain
# 4   01-01-2023  new york           20         11  sunny
# 5   02-01-2023  new york           19         13    fog
# 6   03-01-2023  new york           17          9   snow
# 7   04-01-2023  new york           18         10  sunny
# 8   01-01-2023     patna           30         12  sunny
# 9   02-01-2023     patna           35          9    fog
# 10  03-01-2023     patna           29         10  sunny
# 11  04-01-2023     patna           34          8   rain

# %% [markdown]
# # GROUP BY

# %%
g = df.groupby('city')
g

# %%
for city, city_df in g:
    print(city)
    print(city_df)
# Out:
# mumbai
#           day    city  temperature  windspeed  event
# 0  01-01-2023  mumbai           32          7  sunny
# 1  02-01-2023  mumbai           30          9    fog
# 2  03-01-2023  mumbai           29          6    fog
# 3  04-01-2023  mumbai           28         10   rain
# new york
#           day      city  temperature  windspeed  event
# 4  01-01-2023  new york           20         11  sunny
# 5  02-01-2023  new york           19         13    fog
# 6  03-01-2023  new york           17          9   snow
# 7  04-01-2023  new york           18         10  sunny
# patna
#            day   city  temperature  windspeed  event
# 8   01-01-2023  patna           30         12  sunny
# 9   02-01-2023  patna           35          9    fog
# 10  03-01-2023  patna           29         10  sunny
# 11  04-01-2023  patna           34          8   rain

# %%
g.get_group('patna')
# Out:
#            day   city  temperature  windspeed  event
# 8   01-01-2023  patna           30         12  sunny
# 9   02-01-2023  patna           35          9    fog
# 10  03-01-2023  patna           29         10  sunny
# 11  04-01-2023  patna           34          8   rain

# %%
g.max()
# Out:
#                  day  temperature  windspeed  event
# city
# mumbai    04-01-2023           32         10  sunny
# new york  04-01-2023           20         13  sunny
# patna     04-01-2023           35         12  sunny

# %% [markdown]
# # CONCAT

# %%
india_weather = pd.DataFrame({
    'city':['patna', 'delhi', 'chennai'],
    'temperature':[30, 32, 25],
    'humidity':[80, 78, 76]
})
india_weather
# Out:
#       city  temperature  humidity
# 0    patna           30        80
# 1    delhi           32        78
# 2  chennai           25        76

# %%
us_weather = pd.DataFrame({
    'city': ['new york', 'chicago', 'orlando'],
    'temperature':[25, 23, 24],
    'humidity':[79, 77, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           25        79
# 1   chicago           23        77
# 2   orlando           24        75

# %%
df = pd.concat([india_weather, us_weather])
df
# Out:
#        city  temperature  humidity
# 0     patna           30        80
# 1     delhi           32        78
# 2   chennai           25        76
# 0  new york           25        79
# 1   chicago           23        77
# 2   orlando           24        75

# %%
df = pd.concat([india_weather, us_weather], ignore_index = True)
df
# Out:
#        city  temperature  humidity
# 0     patna           30        80
# 1     delhi           32        78
# 2   chennai           25        76
# 3  new york           25        79
# 4   chicago           23        77
# 5   orlando           24        75

# %%
df = pd.concat([india_weather, us_weather], keys = ['India', 'US'])
df
# Out:
#              city  temperature  humidity
# India 0     patna           30        80
#       1     delhi           32        78
#       2   chennai           25        76
# US    0  new york           25        79
#       1   chicago           23        77
#       2   orlando           24        75

# %%
temperature_df = pd.DataFrame({
    'city': ['patna', 'banglore', 'kolkata'],
    'temperature':[34, 32, 31]
})
temperature_df
# Out:
#        city  temperature
# 0     patna           34
# 1  banglore           32
# 2   kolkata           31

# %%
windspeed_df = pd.DataFrame({
    'city': ['patna', 'banglore', 'kolkata'],
    'windspeed':[11, 10, 8]
})
windspeed_df
# Out:
#        city  windspeed
# 0     patna         11
# 1  banglore         10
# 2   kolkata          8

# %%
df = pd.merge(temperature_df, windspeed_df)
df
# Out:
#        city  temperature  windspeed
# 0     patna           34         11
# 1  banglore           32         10
# 2   kolkata           31          8
